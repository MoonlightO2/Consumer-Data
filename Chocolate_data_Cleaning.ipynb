# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonlightO2/Consumer-Data/blob/main/Chocolate_data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chocolate Data - Cleaning**
#
# ***Datasets***: https://www.kaggle.com/datasets/soroushghaderi/chocolate-bar-2020, https://www.kaggle.com/datasets/rtatman/chocolate-bar-ratings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolate taste.csv'
file2 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolate.csv'
file3 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Cocoa flavours.csv'
file4 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolate tastes.csv'
file5 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolates.csv'
file6 = '/content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Cocoa flavours.csv'

# %% [markdown]
# ## **Dataset 1 - Chocolate taste**

# %%
data1 = pd.read_csv(file1)
print('Shape: ', data1.shape, '\n')
print('Columns: ', data1.columns.tolist(), '\n')
data1.head()
# Out:
# Shape:  (840, 2)
#
# Columns:  ['taste', 'count_of_taste']
#     taste  count_of_taste
# 0   nutty             238
# 1   sweet             237
# 2   cocoa             203
# 3  roasty             198
# 4  creamy             184

# %%
data1.rename(columns={
    'taste': 'Taste',
    'count_of_taste': 'Taste Rate'
}, inplace=True)

# %%
data1 = data1.applymap(lambda x: x.title() if isinstance(x, str) else x)
data1.head()
# Out:
#     Taste  Taste Rate
# 0   Nutty         238
# 1   Sweet         237
# 2   Cocoa         203
# 3  Roasty         198
# 4  Creamy         184

# %%
data1.to_csv(file4, index=False)
print('Cleaned file creation successful...!!', file4)
# Out:
# Cleaned file creation successful...!! /content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolate tastes.csv

# %%
print('Shape: ', data1.shape, '\n')
print('Columns: ', data1.columns.tolist(), '\n')
data1.head()
# Out:
# Shape:  (840, 2)
#
# Columns:  ['Taste', 'Taste Rate']
#     Taste  Taste Rate
# 0   Nutty         238
# 1   Sweet         237
# 2   Cocoa         203
# 3  Roasty         198
# 4  Creamy         184

# %% [markdown]
# ## **Dataset 2 - Chocolate**

# %%
data2 = pd.read_csv(file2)
print('Shape: ', data2.shape, '\n')
print('Columns: ', data2.columns.tolist(), '\n')
data2.head()
# Out:
# Shape:  (2224, 21)
#
# Columns:  ['Unnamed: 0', 'ref', 'company', 'company_location', 'review_date', 'country_of_bean_origin', 'specific_bean_origin_or_bar_name', 'cocoa_percent', 'rating', 'counts_of_ingredients', 'beans', 'cocoa_butter', 'vanilla', 'lecithin', 'salt', 'sugar', 'sweetener_without_sugar', 'first_taste', 'second_taste', 'third_taste', 'fourth_taste']
#    Unnamed: 0   ref   company company_location  review_date  \
# 0           0  2454      5150            U.S.A         2019
# 1           1  2458      5150            U.S.A         2019
# 2           2  2454      5150            U.S.A         2019
# 3           3   797  A. Morin           France         2012
# 4           4   797  A. Morin           France         2012
#
#   country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0             Madagascar           Bejofo Estate, batch 1           76.0
# 1     Dominican republic                  Zorzal, batch 1           76.0
# ...

# %%
# Assuming data2 is your DataFrame
data2 = data2.drop('Unnamed: 0', axis=1)

# %%
data2.rename(columns={
    'ref': 'Ref',
    'company': 'Company',
    'company_location': 'Location',
    'review_date': 'Review Date',
    'country_of_bean_origin': 'Bean Origin',
    'specific_bean_origin_or_bar_name': 'Specific Bean Origin or Bar Name',
    'cocoa_percent': 'Cocoa Percent',
    'rating': 'Rating',
    'counts_of_ingredients': 'Counts of Ingredients',
    'beans': 'Beans',
    'cocoa_butter': 'Cocoa Butter',
    'vanilla': 'Vanilla',
    'lecithin': 'Lecithin',
    'salt': 'Salt',
    'sugar': 'Sugar',
    'sweetener_without_sugar': 'Sweetener without Sugar',
    'first_taste': 'Taste 1',
    'second_taste': 'Taste 2',
    'third_taste': 'Taste 3',
    'fourth_taste': 'Taste 4'
}, inplace=True)

# %%
data2 = data2.applymap(lambda x: x.title().replace('_', ' ').strip() if isinstance(x, str) else x)

# %%
# Define a dictionary to map old values to new values for each column
rename_mapping = {
    'Beans': {'Have Bean': 'Bean'},
    'Cocoa Butter': {'Have Cocoa Butter': 'Yes', 'Have Not Cocoa Butter': 'No'},
    'Vanilla': {'Have Not Vanila': 'No', 'Have Vanila': 'Yes'},
    'Lecithin': {'Have Not Lecithin': 'No', 'Have Lecithin': 'Yes'},
    'Salt': {'Have Not Salt': 'No', 'Have Salt': 'Yes'},
    'Sugar': {'Have Sugar': 'Yes', 'Have Not Sugar': 'No'},
    'Sweetener without Sugar': {'Have Not Sweetener Without Sugar': 'No', 'Have Sweetener Without Sugar': 'Yes'}
}

# Iterate over each column and apply the mapping
for col, mapping in rename_mapping.items():
    data2[col] = data2[col].replace(mapping)

# %%
cols = ['Beans', 'Cocoa Butter', 'Vanilla', 'Lecithin', 'Salt', 'Sugar', 'Sweetener without Sugar']

for col in cols:
  unique_count = data2[col].nunique()
  print(f"Unique values in '{col}':", unique_count)
  print(f"Unique values in '{col}':", data2[col].unique(), '\n')
# Out:
# Unique values in 'Beans': 1
# Unique values in 'Beans': ['Bean']
#
# Unique values in 'Cocoa Butter': 2
# Unique values in 'Cocoa Butter': ['Yes' 'No']
#
# Unique values in 'Vanilla': 2
# Unique values in 'Vanilla': ['No' 'Yes']
#
# Unique values in 'Lecithin': 2
# Unique values in 'Lecithin': ['No' 'Yes']
#
# Unique values in 'Salt': 2
# Unique values in 'Salt': ['No' 'Yes']
#
# Unique values in 'Sugar': 2
# Unique values in 'Sugar': ['Yes' 'No']
#
# Unique values in 'Sweetener without Sugar': 2
# Unique values in 'Sweetener without Sugar': ['No' 'Yes']

# %%
data2.to_csv(file5, index=False)
print('Cleaned file creation successful...!!', file5)
# Out:
# Cleaned file creation successful...!! /content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Chocolates.csv

# %%
print('Shape: ', data2.shape, '\n')
print('Columns: ', data2.columns.tolist(), '\n')
data2.head()
# Out:
# Shape:  (2224, 20)
#
# Columns:  ['Ref', 'Company', 'Location', 'Review Date', 'Bean Origin', 'Specific Bean Origin or Bar Name', 'Cocoa Percent', 'Rating', 'Counts of Ingredients', 'Beans', 'Cocoa Butter', 'Vanilla', 'Lecithin', 'Salt', 'Sugar', 'Sweetener without Sugar', 'Taste 1', 'Taste 2', 'Taste 3', 'Taste 4']
#     Ref   Company Location  Review Date         Bean Origin  \
# 0  2454      5150    U.S.A         2019          Madagascar
# 1  2458      5150    U.S.A         2019  Dominican Republic
# 2  2454      5150    U.S.A         2019            Tanzania
# 3   797  A. Morin   France         2012                Peru
# 4   797  A. Morin   France         2012             Bolivia
#
#   Specific Bean Origin or Bar Name  Cocoa Percent  Rating  \
# 0           Bejofo Estate, Batch 1           76.0    3.75
# 1                  Zorzal, Batch 1           76.0    3.50
# 2            Kokoa Kamili, Batch 1           76.0    3.25
# 3                             Peru           63.0    3.75
# ...

# %% [markdown]
# ## **Dataset 3 - Flavors of Cocoa**

# %%
data3 = pd.read_csv(file3)
print('Shape: ', data3.shape, '\n')
print('Columns: ', data3.columns.tolist(), '\n')
data3.head()
# Out:
# Shape:  (1795, 9)
#
# Columns:  ['Company\xa0\n(Maker-if known)', 'Specific Bean Origin\nor Bar Name', 'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating', 'Bean\nType', 'Broad Bean\nOrigin']
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# ...

# %%
data3 = data3.rename(columns={
    'Company\xa0\n(Maker-if known)': 'Company',
    'Specific Bean Origin\nor Bar Name': 'Specific Bean Origin or Bar Name',
    'Review\nDate': 'Review Date',
    'Cocoa\nPercent': 'Cocoa Percent',
    'Company\nLocation': 'Location',
    'Bean\nType': 'Bean Type',
    'Broad Bean\nOrigin': 'Broad Bean Origin'
})

# %%
data3 = data3[['Company', 'Location', 'Specific Bean Origin or Bar Name', 'Broad Bean Origin', 'Bean Type', 'Cocoa Percent', 'REF', 'Review Date', 'Rating']]
data3.to_csv(file6, index=False)
print('Cleaned file creation successful...!!', file6)
# Out:
# Cleaned file creation successful...!! /content/drive/MyDrive/Projects/Portfolio/Consumer Products/Chocolate/Cocoa flavours.csv

# %%
print('Shape: ', data3.shape, '\n')
print('Columns: ', data3.columns.tolist(), '\n')
data3.head()
# Out:
# Shape:  (1795, 9)
#
# Columns:  ['Company', 'Location', 'Specific Bean Origin or Bar Name', 'Broad Bean Origin', 'Bean Type', 'Cocoa Percent', 'REF', 'Review Date', 'Rating']
#     Company Location Specific Bean Origin or Bar Name Broad Bean Origin  \
# 0  A. Morin   France                      Agua Grande          Sao Tome
# 1  A. Morin   France                            Kpime              Togo
# 2  A. Morin   France                           Atsane              Togo
# 3  A. Morin   France                            Akata              Togo
# 4  A. Morin   France                           Quilla              Peru
#
#   Bean Type Cocoa Percent   REF  Review Date  Rating
# 0                     63%  1876         2016    3.75
# 1                     70%  1676         2015    2.75
# 2                     70%  1676         2015    3.00
# 3                     70%  1680         2015    3.50
# 4                     70%  1704         2015    3.50
